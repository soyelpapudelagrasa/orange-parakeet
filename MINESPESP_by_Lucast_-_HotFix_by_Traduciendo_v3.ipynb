# %%
# Esta es una modificacion del script original para google colab, para que funcione en github codespaces
# Hecho por @LUCAST o @Lucast1574 o @Lucast_1574 en github y otras redes sociales
# Solo versiones +1.17
# Versiones disponibles testeadas:
# - 1.20.4
# - 1.20.3
# - 1.20.2
# - 1.20.1
# - 1.20
# - 1.19.4
# - 1.19.3
# - 1.19.2
# - 1.19.1
# - 1.19
# - 1.18.2
# - 1.18.1
# - 1.18
# - 1.17.1
# - Para versiones antiguas, ya esta disponible a exepcion de forge, seguir los pasos para usar un forge antiguo



version = '1.20.1' # Version de Minecraft a usar

#Chose server type. Currently available versions:
# - paper (Lo más vanilla. Es lo mismo que SPIGOT, bukkit, etc)
# - forge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO]
# - oldforge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO] Solo para versiones antiguas -1.17
# - fabric (Para jugar Fabric. Es una alternativa a Forge)
# - vanilla (Minecraft Vanilla sin mods ni plugins)
# - snapshot (En "version" tendrás que poner el nombre de la SNAPSHOT, EJ: 23w42a)
# - mohist (Versión de Minecraft que combina Forge y Bukkit) 1.20.1 29/09/24 ultima version disponible
# - catserver (Versión de Minecraft que combina Forge y Bukkit) 1.18.2 29/09/24 ultima version disponible
# - purpur (Versión de Minecraft que combina paper y Bukkit)

# Para usar paper primero tienes que instalar el vanilla
# Para usar mohist primero tienes que instalar el forge
# Para usar catserver primero tienes que instalar el forge
# Para usar purpur primero tienes que instalar el fabric

server_type = 'mohist'

#Importa librerias necesarias para el funcionamiento del script 

import os
import requests
import json


server_directory = "Minecraft-server"

# Crea el directorio del servidor en codespace

os.makedirs(server_directory, exist_ok=True)
os.chdir(server_directory)

# Inicio interno... Descarga el servidor 

if server_type == 'paper':
    a = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version)

    b = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]))

    print("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"])
    serverURL = "https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"]

elif server_type == 'forge':
    serverURL = "https://serverjars.com/api/fetchJar/modded/forge/" + version

elif server_type == 'vanilla':
    serverURL = "https://piston-data.mojang.com/v1/objects/8dd1a28015f51b1803213892b50b7b4fc76e594d/server.jar"

elif server_type == 'snapshot':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/snapshot/" + version

elif server_type == 'fabric':
    serverURL = 'https://serverjars.com/api/fetchJar/modded/fabric/' + version

elif server_type == 'mohist':
    serverURL = "https://mohistmc.com/api/v2/projects/mohist/1.20.1/builds/603/mohist-1.20.1-603-server.jar"
    
elif server_type == 'catserver':
    serverURL = "https://jenkins.rbqcloud.cn:30011/job/CatServer-1.18.2/lastSuccessfulBuild/artifact/projects/forge/build/libs/CatServer-1.18.2-3cdd17ea-server.jar"

elif server_type == 'purpur':
    serverURL = "https://serverjars.com/api/fetchJar/servers/purpur/" + version

# Lista de nombres de los archivos

jar_name = {'paper': 'paper.jar', 'fabric': 'fabric-server-launch.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': "snapshot.jar", 'mohist': "mohist-1.20.1-603-server.jar", 
            'catserver': "catserver.jar", 'purpur': "purpur.jar"}

print('Descargando el tipo de servidor: ')

if serverURL:
    print('Descargando a GitHub Codespaces...')
    r = requests.get(serverURL)

    if r.status_code == 200:
        with open(jar_name[server_type], 'wb') as f:
            f.write(r.content)
    else:
        print('Error '+ str(r.status_code) + '! La versión que has elegido probablemente no funciona.')


# Correr en un camino especifico

if server_type == 'fabric':
    # !java -jar fabric-server-launch.jar server -mcversion $version -downloadMinecraft

if server_type == 'forge':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar forge.jar --installServer

if server_type == 'vanilla':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar vanilla.jar --installServer

# Guarda el archivo de configuración localmente
colabconfig = {"server_type": server_type, "server_version": version}
with open("colabconfig.json", 'w') as config_file:
    json.dump(colabconfig, config_file)

# Imprime un mensaje de finalización
print('Completado!')
# Cambie el eula a true para aceptar los términos de Minecraft
# !echo "eula=true" >> eula.txt
# Out:
# Descargando el tipo de servidor:
# Descargando a GitHub Codespaces...
# Completado!

# %%
#Tienes que poner el spawn proteccion en 0 para que puedas jugar de manera normal(esto dentro de Server.properties)
#importa librerias necesarias para ejecucion

import requests

import time

import os

import re

import json

import glob

import threading

import subprocess


#Actualizacion de lista de paquetes

# !sudo apt update &>/dev/null && echo "el apt cache fue actualizado correctamente" || echo "la actualizacion del apt cache fallo, es posible que recibas paquetes obsoletos"

#Asignar archivos al directorio


os.makedirs("/workspaces/codespaces-jupyter/Minecraft-server", exist_ok=True)

os.chdir("/workspaces/codespaces-jupyter/Minecraft-server")

# !ls #lista los archivos del directorio para verificarlos



#Importacion del archivo de configuracion


config_path = "/workspaces/codespaces-jupyter/Minecraft-server/colabconfig.json"

if os.path.isfile(config_path):

    with open(config_path) as config_file:

        colabconfig = json.load(config_file)

else:

    colabconfig = {"server_type": "generic"} # Usar la configura default si no existe

    with open(config_path, 'w') as new_config_file:

        json.dump(colabconfig, new_config_file)

# Instalar OpenJDK

version = colabconfig["server_version"]

# Ejecuta un comando en la terminal

def installjava17(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 17 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 17")

def installjava11(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 11 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 11")

def installjava8(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 8 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 8")
        
def purgejava(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK purgado correctamente")
    else:
        print("Fallo al purgar OpenJDK")

# Instala OpenJDK 17 si la versión de Minecraft es 1.17 o superior
# Si la versión es inferior, instala OpenJDK 8

if version < "1.14":
    # Purga versiones anteriores de OpenJDK
    purgejava('sudo apt-get purge openjdk* -y')
    # Instala OpenJDK 8
    installjava8('sudo apt-get install openjdk-8-jre-headless -y')

elif version >= "1.14" and version < "1.17":
    # Purga versiones anteriores de OpenJDK
    purgejava('sudo apt-get purge openjdk* -y')
    # Instala OpenJDK 11
    installjava11('sudo apt-get install openjdk-11-jre-headless -y')

else:
    # Purga versiones anteriores de OpenJDK
    purgejava('sudo apt-get purge openjdk* -y')
    # Instala OpenJDK 17
    installjava17('sudo apt-get install openjdk-17-jre-headless -y')

# Chequeo de version de java

java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'

#Lista de posibles archivos .jar

jar_list = {'paper': 'paper.jar', 'fabric': 'fabric-server-launch.jar', 'generic': 'server.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': 'snapshot.jar', 'mohist': "mohist-1.20.1-603-server.jar", 'catserver': "catserver.jar", 'purpur': "purpur.jar"}

jar_name = jar_list[colabconfig["server_type"]]

# Argumentos de java.

if colabconfig["server_type"] == "paper":

    server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"

else:

    server_flags = "" # No se necesitan banderas para servidores que no sean de paper

#Argumentos JVM

memory_allocation = "-Xms10G -Xmx10G"



# Elige el servicio de tunelacion que desees

# Opciones disponibles: ngrok

tunnel_service = "ngrok"

print("Usando", tunnel_service)


#Condicional de tunelacion del servidor



if tunnel_service == "ngrok":

    # !pip -q install pyngrok  #Aqui se instala el ngrok en el servidor

    from pyngrok import conf, ngrok



    # Obten tu token de ngrok

    print("Consigue tu authtoken de https://dashboard.ngrok.com/auth") #Consigue aqui tu token de ngrok, sera dinamico, si quieres que sea estatico, necesitaras la version premiun de ngrok

    import getpass



    # v - - - - - - - TOKEN - - - - - - - v



    authtoken = "2evuczWsgj4oyZ1tNrWxOO0ulpU_4g6tGummLuUJEozmT7ZEu" # <---- TOKEN NGROK (PON AQUÍ TU TOKEN [TIENE QUE ESTAR ENTRE LAS "COMILLAS"])

    ! ngrok authtoken $authtoken # logeo en ngrok



    #Establecimiento de region de ngrok



    #v - - - - - - - REGIONES DISPONIBLES - - - - - - - v

    # ap - Asia/Pacifico (Singapore)

    # au - Australia (Sydney)

    # eu - Europa (Frankfurt - Alemania)

    # in - India (Mumbai)

    # jp - Japon (Tokyo)

    # sa - America del sur (São Paulo - Brasil)

    # us - Estados unidos (Ohio)

    conf.get_default().region = 'us' # <--- Cambia esto por la region que quieras



    # Conectar a ngrok

    url = ngrok.connect(25565, 'tcp')

    print('La IP de tu servidor es ' + ((str(url).split('"')[1::2])[0]).replace('tcp://', ''))

    #Si obtienes el servicio premiun de ngrok borra las dos lineas de codigo de arriba y quitale el # a estas a continuacion:

    #subdominio = "mi-subdominio"

    #url = ngrok.connect(25565, 'tcp', subdomain=subdominio)

    #print('La IP de tu servidor es ' + url.replace('tcp://', ''))


elif tunnel_service == "playit":

    subprocess.run(["curl", "-SsL", "https://playit-cloud.github.io/ppa/key.gpg"], check=True)
    subprocess.run(["sudo", "apt-key", "add", "key.gpg"], check=True)

    # Añadiendo el repositorio de Playit.gg
    subprocess.run(["sudo", "curl", "-SsL", "-o", "/etc/apt/sources.list.d/playit-cloud.list", "https://playit-cloud.github.io/ppa/playit-cloud.list"], check=True)

    # Actualizando la lista de paquetes
    subprocess.run(["sudo", "apt", "update"], check=True)

    # Instalando Playit.gg
    result = subprocess.run(["sudo", "apt", "install", "playit"], stdout=subprocess.PIPE, stderr=subprocess.PIPE)

    # Comprueba si la instalación fue exitosa
    if result.returncode == 0:
        print("Playit.gg installed")
    else:
        print("Failed to install Playit.gg")

    # Iniciando el servidor con Playit.gg
    print('Starting server...')
    subprocess.run(["playit", "&", "java", "$memory_allocation", "$server_flags", "-jar", "$jar_name", "nogui"], check=True)

    # Obteniendo la IP del servidor
    result = subprocess.run(["playit", "status"], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    print("Tu ip es: " + result.stdout.decode())

#Obtiene la lista de usuarios de JSONPlaceholder
#Para mantener el servidor activo
def get_users():
    url = 'https://jsonplaceholder.typicode.com/users'
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            print("Lista de usuarios:")
            for user in data:
                print(f"Nombre: {user['name']}, Email: {user['email']}")
        else:
            print(f"Error al hacer la solicitud. Código de estado: {response.status_code}")
    except requests.RequestException as e:
        print(f"Error de conexión: {e}")

# Función para ejecutar get_users() cada 25 minutos
def repeat_get_users():
    while True:
        get_users()
        time.sleep(600)  # Espera 10 minutos

# Inicia un hilo para ejecutar repeat_get_users() en segundo plano
user_thread = threading.Thread(target=repeat_get_users)
user_thread.start()

#Obtener el archivo de configuracion
stype = colabconfig["server_type"]
version = colabconfig["server_version"]

#Imprimir el tipo de servidor y la version
print("Estas jugando a minecraft: " + stype + " en su version: "+ version)

#Si el servidor es de tipo Forge antiguo no va a funcionar
if colabconfig["server_type"] == "forge" and colabconfig["server_version"] < "1.17.1":
    print("La version de Forge no es compatible con este script. Por favor, usa una version de Forge 1.17.1 o superior.")


#Si el servidor es de tipo Forge encontrara los archivos necesarios para ejecutar el servidor

if colabconfig["server_type"] == "forge":

    # Obtiene la versión de Forge
    
    forgefiles = f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/"
    
    forgepreversion = os.listdir(forgefiles)
        
    if forgepreversion:
        
        forgeversion = forgepreversion[0]
        forgeversionchecked = forgeversion.replace(".jar", "")
        print("La versión de Forge es:", forgeversionchecked)
        
    else:
        
        print("No se encontraron archivos en el directorio Forge.")
        
    pathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/{forgeversionchecked}/unix_args.txt")

    if pathtoforge: # Checa si la lista no esta vacia

        path = pathtoforge[0] # Obtiene la primera ruta de la lista

        print(path)

        # !java @user_jvm_args.txt "@{path}" "$@"

    else:

        print("No se encontro el archivo unix_args.txt.")

#Si el servidor es de tipo Vanilla o paper o mohist o catserver o fabric o purpur

else:

    #Ejecuta el archivo jar del servidor
    
    # !java $memory_allocation $server_flags -jar $jar_name nogui

# Ciclo para realizar las solicitudes a JSONPlaceholder cada minuto

while True:
    time.sleep(60)  # Espera 1 minuto
# Out:
# el apt cache fue actualizado correctamente
# banned-ips.json      libraries			   server.properties
# banned-players.json  logs			   spigot.yml
# bukkit.yml	     mods			   usercache.json
# colabconfig.json     mohist-1.20.1-603-server.jar  usernamecache.json
# commands.yml	     mohist-config		   wepif.yml
# config		     ops.json			   whitelist.json
# eula.txt	     permissions.yml		   world
# help.yml	     plugins
# OpenJDK purgado correctamente
# OpenJDK 17 instalado correctamente
# Usando ngrok
# Consigue tu authtoken de https://dashboard.ngrok.com/auth
# Authtoken saved to configuration file: /home/codespace/.config/ngrok/ngrok.yml
# La IP de tu servidor es 0.tcp.ngrok.io:14357
# Estas jugando a minecraft: mohist en su version: 1.20.1
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
#
#  ███╗   ███╗  ██████╗  ██╗  ██╗ ██╗ ███████╗ ████████╗
#  ████╗ ████║ ██╔═══██╗ ██║  ██║ ██║ ██╔════╝ ╚══██╔══╝
#  ██╔████╔██║ ██║   ██║ ███████║ ██║ ███████╗    ██║
#  ██║╚██╔╝██║ ██║   ██║ ██╔══██║ ██║ ╚════██║    ██║
#  ██║ ╚═╝ ██║ ╚██████╔╝ ██║  ██║ ██║ ███████║    ██║
#  ╚═╝     ╚═╝  ╚═════╝  ╚═╝  ╚═╝ ╚═╝ ╚══════╝    ╚═╝
#
# Thanks for using Mohist - 1.20.1-639, Java(21.0.2) 65.0 PID: 29789
# Update in check...
# If you don't want to enable update check, set check_update in mohist-config/mohist.yml to false
# The latest Mohist version is 661 but you have 639. The latest version has been built on 2024-04-10 10:02:26. You should update to fix recent bugs!
# Checking libraries, please wait...
# All libraries are nice :)!
# Searching incompatible mods...
# [01:19:38 INFO]: ModLauncher running: args [--launchTarget, forgeserver, --fml.forgeVersion, 47.2.21, --fml.mcVersion, 1.20.1, --fml.forgeGroup, net.minecraftforge, --fml.mcpVersion, 20230612.114412, nogui]
# [01:19:38 INFO]: ModLauncher 10.0.9+10.0.9+main.dcd20f30 starting: java version 21.0.2 by Microsoft; OS Linux arch amd64 version 6.2.0-1019-azure
# [01:19:39 INFO]: ImmediateWindowProvider not loading because launch target is forgeserver
# [01:19:39 INFO]: SpongePowered MIXIN Subsystem Version=0.8.5 Source=union:/workspaces/codespaces-jupyter/Minecraft-server/libraries/org/spongepowered/mixin/0.8.5/mixin-0.8.5.jar%23111!/ Service=ModLauncher Env=SERVER
# [01:19:39 INFO]: Found 2 dependencies adding them to mods collection
# [01:19:40 INFO]: Compatibility level set to JAVA_17
# [01:19:40 INFO]: Launching target 'forgeserver' with arguments [nogui]
# [01:19:47 INFO]: Mohist mod loading.....
# [01:19:47 INFO]: Forge mod loading, version 47.2.21, for MC 1.20.1 with MCP 20230612.114412
# [01:19:47 INFO]: MinecraftForge v47.2.21 Initialized
# [01:19:47 INFO]: NeoForge v47.2.21 Initialized
# [01:19:47 INFO]: EventDispatcherRegistry initialized
# [01:19:48 INFO]: [voicechat] Compatibility version 18
# [01:19:48 INFO]: [voicechat] Loading plugins
# [01:19:48 INFO]: [voicechat] Loaded 0 plugin(s)
# [01:19:48 INFO]: [voicechat] Initializing plugins
# [01:19:48 INFO]: [voicechat] Initialized 0 plugin(s)
# [01:19:48 INFO]: Got IMC []
# [01:19:50 INFO]: Environment: authHost='https://authserver.mojang.com', accountsHost='https://api.mojang.com', sessionHost='https://sessionserver.mojang.com', servicesHost='https://api.minecraftservices.com', name='PROD'
# [01:19:52 INFO]: Adding datapack listener capsid_recipes
# [01:19:53 INFO]: Loaded 7 recipes
# [01:19:53 INFO]: Loaded 1396 advancements
# [01:19:53 INFO]: Starting minecraft server version 1.20.1
# [01:19:53 INFO]: Loading properties
# [01:19:53 INFO]: Default game type: SURVIVAL
# [01:19:53 INFO]: Generating keypair
# [01:19:53 INFO]: Starting Minecraft server on *:25565
# [01:19:53 INFO]: Using epoll channel type
# [01:19:54 WARN]: **** SERVER IS RUNNING IN OFFLINE/INSECURE MODE!
# [01:19:54 WARN]: The server will make no attempt to authenticate usernames. Beware.
# [01:19:54 WARN]: While this makes the game possible to play without internet access, it also opens up the ability for hackers to connect with any username they choose.
# [01:19:54 WARN]: To change this, set "online-mode" to "true" in the server.properties file.
# [01:19:54 INFO]: This server is running Mohist version 1.20.1-639 (MC: 1.20.1) (Implementing API version 1.20.1-R0.1-SNAPSHOT, Forge version 47.2.21, NeoForge version 47.1.79)
# [01:19:54 INFO]: Debug logging is enabled
# [01:19:54 INFO]: Server Ping Player Sample Count: 20
# [01:19:54 INFO]: Using 4 threads for Netty based IO
# [01:19:57 INFO]: [WolfyUtilities] Loading 3 libraries... please wait
# [01:19:57 INFO]: [WolfyUtilities] Loading -1 extra libraries... please wait
# [01:19:57 INFO]: [WolfyUtilities] Found libraries libraries/plugins-lib/com/google/inject/guice/5.1.0/guice-5.1.0.jar
# [01:19:57 INFO]: [WolfyUtilities] Found libraries libraries/plugins-lib/it/unimi/dsi/fastutil/8.5.6/fastutil-8.5.6.jar
# [01:19:57 INFO]: [WolfyUtilities] Loaded libraries libraries/plugins-lib/com/google/inject/guice/5.1.0/guice-5.1.0.jar
# [01:19:57 INFO]: [WolfyUtilities] Loaded libraries libraries/plugins-lib/it/unimi/dsi/fastutil/8.5.6/fastutil-8.5.6.jar
# [01:19:59 INFO]: [WolfyUtilities] NMS Version: v1_20_R1
# [01:19:59 INFO]: Reflections took 483 ms to scan 1 urls, producing 915 keys and 3672 values
# [01:19:59 INFO]: [WolfyUtilities] Register Default StackIdentifiers
# [01:20:00 WARN]: [CustomCrafting] Paper not detected! Not using performance improvements.
# [01:20:00 INFO]: [CustomCrafting] NMS Version: v1_20_R1
# [01:20:00 INFO]: [WorldEdit] Loading WorldEdit v7.2.20+6667-f0f1e66
# [01:20:01 INFO]: Got request to register class com.sk89q.worldedit.bukkit.BukkitServerInterface with WorldEdit [com.sk89q.worldedit.extension.platform.PlatformManager@53409a22]
# [01:20:01 INFO]: [SkinsRestorer] Loading SkinsRestorer v15.0.8
# [01:20:01 INFO]: [Permadeath] Loading Permadeath v1.3
# [01:20:01 INFO]: [WorldGuard] Loading WorldGuard v7.0.9+5934e49
# [01:20:01 INFO]: [Shopkeepers] Loading Shopkeepers v2.19.0
# [01:20:02 INFO]: [Shopkeepers] Loaded all plugin classes (759 ms).
# [01:20:02 INFO]: [Shopkeepers] Loading config.
# [01:20:02 WARN]: [Shopkeepers] Config: Forcefully enabled 'disable-inventory-verification' to resolve a known incompatibility with Mohist servers.
# [01:20:02 INFO]: [Shopkeepers] Loading language file: language-en-default.yml
# [01:20:02 INFO]: [Shopkeepers] Registering WorldGuard flag 'allow-shop'.
# [01:20:02 INFO]: [Shopkeepers] Registering defaults.
# [01:20:02 INFO]: [WolfyUtilities] Loading WolfyUtilities v4.16.15.1
# [01:20:02 INFO]: [WolfyUtilities] Register JSON de-/serializers
# [01:20:02 INFO]: [WolfyUtilities] Register JSON Operators
# [01:20:02 INFO]: [WolfyUtilities] Register JSON Value Providers
# [01:20:02 INFO]: [WolfyUtilities] Register CustomItem NBT Checks
# [01:20:02 INFO]: [WolfyUtilities] Register CustomItem Actions
# [01:20:02 INFO]: [WolfyUtilities] Register CustomItem Events
# [01:20:02 INFO]: [WolfyUtilities] Register Particle Animators
# [01:20:02 INFO]: [WolfyUtilities] Register Particle Shapes
# [01:20:02 INFO]: [WolfyUtilities] Register Particle Timers
# [01:20:02 INFO]: [WolfyUtilities] Register Custom Block Data
# [01:20:02 INFO]: [WolfyUtilities] Register Custom Player Data
# [01:20:02 INFO]: [WolfyUtilities] Register NBT Query Nodes
# [01:20:02 INFO]: [CustomCrafting] Loading CustomCrafting v4.16.9.1
# [01:20:02 INFO]: [CustomCrafting] WolfyUtils API: v4.16.15.1
# [01:20:02 INFO]: [CustomCrafting] CustomCrafting: v4.16.9.1
# [01:20:02 INFO]: [CustomCrafting] Environment   : PROD
# [01:20:02 INFO]: [CustomCrafting] Registering CustomItem Data
# [01:20:02 INFO]: [CustomCrafting] Registering Custom Block Data
# [01:20:02 INFO]: [CustomCrafting] Registering Result Extensions
# [01:20:02 INFO]: [CustomCrafting] Registering Result Merge Adapters
# [01:20:03 INFO]: [CustomCrafting] Registering Recipe Conditions
# [01:20:03 INFO]: [CustomCrafting] Registering Recipe Types
# [01:20:03 INFO]: [CustomCrafting] Registering Anvil Recipe Tasks
# [01:20:03 INFO]: [CustomCrafting] Registering Type Registries
# [01:20:03 INFO]: [WorldEdit] Enabling WorldEdit v7.2.20+6667-f0f1e66
# [01:20:03 INFO]: Registering commands with com.sk89q.worldedit.bukkit.BukkitServerInterface
# [01:20:03 INFO]: WEPIF: Using the Bukkit Permissions API.
# [01:20:05 INFO]: Using com.sk89q.worldedit.bukkit.adapter.impl.v1_20_R1.PaperweightAdapter as the Bukkit adapter
# [01:20:06 INFO]: [WorldEdit] ====================================================
# [01:20:06 INFO]: [WorldEdit]  WorldEdit works better if you use Paper
# [01:20:06 INFO]: [WorldEdit]  as your server software.
# [01:20:06 INFO]: [WorldEdit]
# [01:20:06 INFO]: [WorldEdit]  Paper offers significant performance improvements,
# [01:20:06 INFO]: [WorldEdit]  bug fixes, security enhancements and optional
# [01:20:06 INFO]: [WorldEdit]  features for server owners to enhance their server.
# [01:20:06 INFO]: [WorldEdit]
# [01:20:06 INFO]: [WorldEdit]  Paper includes Timings v2, which is significantly
# [01:20:06 INFO]: [WorldEdit]  better at diagnosing lag problems over v1.
# [01:20:06 INFO]: [WorldEdit]
# [01:20:06 INFO]: [WorldEdit]  All of your plugins should still work, and the
# [01:20:06 INFO]: [WorldEdit]  Paper community will gladly help you fix any issues.
# [01:20:06 INFO]: [WorldEdit]
# [01:20:06 INFO]: [WorldEdit]  Join the Paper Community @ https://papermc.io
# [01:20:06 INFO]: [WorldEdit] ====================================================
# [01:20:06 INFO]: [SkinsRestorer] Enabling SkinsRestorer v15.0.8
# [01:20:07 INFO]: [SkinsRestorer] Running on Minecraft 1.20.1.
# [01:20:08 INFO]: [Permadeath] Enabling Permadeath v1.3
# [01:20:08 INFO]: [WolfyUtilities] Enabling WolfyUtilities v4.16.15.1
# [01:20:08 INFO]: [WolfyUtilities] Minecraft version: 1.20.1
# [01:20:08 INFO]: [WolfyUtilities] WolfyUtils version: 4.16.15.1
# [01:20:08 INFO]: [WolfyUtilities] Environment: PROD
# [01:20:08 INFO]: [WolfyUtilities] Loading Plugin integrations:
# [01:20:08 INFO]: [WolfyUtilities]  - No integrations found
# [01:20:08 INFO]: [WolfyUtilities] Register API references
# [01:20:08 INFO]: [WolfyUtilities] Loading stored Custom Items
# [01:20:08 INFO]: [WolfyUtilities] Loading Creative Mode Tabs
# [01:20:08 INFO]: Preparing level "world"
# [01:20:13 INFO]: Preparing start region for dimension minecraft:overworld
# [01:20:17 INFO]: Preparing spawn area: 0%
# [01:20:17 INFO]: Preparing spawn area: 0%
# [01:20:17 INFO]: Preparing spawn area: 0%
# [01:20:17 INFO]: Preparing spawn area: 0%
# [01:20:17 INFO]: Preparing spawn area: 0%
# [01:20:17 INFO]: Preparing spawn area: 0%
# [01:20:17 INFO]: Preparing spawn area: 0%
# [01:20:17 INFO]: Preparing spawn area: 0%
# [01:20:17 INFO]: Preparing spawn area: 0%
# [01:20:17 INFO]: Preparing spawn area: 0%
# [01:20:18 INFO]: Preparing spawn area: 4%
# [01:20:18 INFO]: Preparing spawn area: 68%
# [01:20:18 INFO]: Time elapsed: 5802 ms
# [01:20:19 INFO]: Preparing start region for dimension minecraft:the_end
# [01:20:20 INFO]: Preparing spawn area: 0%
# [01:20:20 INFO]: Preparing spawn area: 0%
# [01:20:20 INFO]: Preparing spawn area: 0%
# [01:20:20 INFO]: Preparing spawn area: 0%
# [01:20:20 INFO]: Time elapsed: 1968 ms
# [01:20:20 INFO]: Preparing start region for dimension minecraft:the_nether
# [01:20:22 INFO]: Preparing spawn area: 0%
# [01:20:22 INFO]: Preparing spawn area: 0%
# [01:20:22 INFO]: Preparing spawn area: 0%
# [01:20:22 INFO]: Preparing spawn area: 0%
# [01:20:22 INFO]: Time elapsed: 1969 ms
# [01:20:22 INFO]: [WorldGuard] Enabling WorldGuard v7.0.9+5934e49
# [01:20:23 INFO]: [WorldGuard] (world) TNT ignition is PERMITTED.
# [01:20:23 INFO]: [WorldGuard] (world) Lighters are PERMITTED.
# [01:20:23 INFO]: [WorldGuard] (world) Lava fire is PERMITTED.
# [01:20:23 INFO]: [WorldGuard] (world) Fire spread is UNRESTRICTED.
# [01:20:23 INFO]: [WorldGuard] Loaded configuration for world 'world'
# [01:20:23 INFO]: [WorldGuard] (DIM1) TNT ignition is PERMITTED.
# [01:20:23 INFO]: [WorldGuard] (DIM1) Lighters are PERMITTED.
# [01:20:23 INFO]: [WorldGuard] (DIM1) Lava fire is PERMITTED.
# [01:20:23 INFO]: [WorldGuard] (DIM1) Fire spread is UNRESTRICTED.
# [01:20:23 INFO]: [WorldGuard] Loaded configuration for world 'DIM1'
# [01:20:23 INFO]: [WorldGuard] (DIM-1) TNT ignition is PERMITTED.
# [01:20:23 INFO]: [WorldGuard] (DIM-1) Lighters are PERMITTED.
# [01:20:23 INFO]: [WorldGuard] (DIM-1) Lava fire is PERMITTED.
# [01:20:23 INFO]: [WorldGuard] (DIM-1) Fire spread is UNRESTRICTED.
# [01:20:23 INFO]: [WorldGuard] Loaded configuration for world 'DIM-1'
# [01:20:23 INFO]: [WorldGuard] Loading region data...
# [01:20:23 INFO]: [Shopkeepers] Enabling Shopkeepers v2.19.0
# [01:20:23 INFO]: [Shopkeepers] Loading the data of 6 shopkeepers ...
# [01:20:23 INFO]: [CustomCrafting] Enabling CustomCrafting v4.16.9.1
# [01:20:23 INFO]: [CustomCrafting] Loaded fallback language "en_US" v6.1.0 translated by WolfyScript
# [01:20:24 INFO]: [CustomCrafting] Loaded active language "en_US" v6.1.0 translated by WolfyScript
# [01:20:24 INFO]: [CustomCrafting] ____ _  _ ____ ___ ____ _  _ ____ ____ ____ ____ ___ _ _  _ ____
# [01:20:24 INFO]: [CustomCrafting] |    |  | [__   |  |  | |\/| |    |__/ |__| |___  |  | |\ | | __
# [01:20:24 INFO]: [CustomCrafting] |___ |__| ___]  |  |__| |  | |___ |  \ |  | |     |  | | \| |__]
# [01:20:24 INFO]: [CustomCrafting]     Version      | v4.16.9.1
# [01:20:24 INFO]: [CustomCrafting]     WolfyUtils   | v4.16.15.1
# [01:20:24 INFO]: [CustomCrafting]     Bukkit       | 1.20.1-639 (MC: 1.20.1)(API: 1.20.1-R0.1-SNAPSHOT)
# [01:20:24 INFO]: [NBTAPI] Found Spigot: v1_20_R1! Trying to find NMS support
# [01:20:24 INFO]: [NBTAPI] NMS support 'MC1_20_R1' loaded!
# [01:20:24 INFO]: [NBTAPI] Using the plugin 'WolfyUtilities' to create a bStats instance!
# [01:20:24 INFO]: [CustomCrafting]
# [01:20:24 INFO]: [CustomCrafting] Special thanks to my Patrons for supporting this project:
# [01:20:24 INFO]: [CustomCrafting] Omarlatif, Nat R, Obsidian_Sword, LiveJunye, Mithran, Teddy
# [01:20:24 INFO]: [CustomCrafting] Invictus_Vulpes , Luuk Musch, fioxu, JorshStark, Perny Dev, Charlie
# [01:20:24 INFO]: [CustomCrafting] iachen, whja t, Green Masks, lance fector, Jack Snellings, MineHouse Server
# [01:20:24 INFO]: [CustomCrafting] ------------------------------------------------------------------------
# [01:20:24 INFO]: [CustomCrafting] Data destination: LOCAL
# [01:20:24 INFO]: [CustomCrafting] Initiating Inventory GUIs
# [01:20:24 INFO]: [CustomCrafting] Register ItemCreator Tabs
# [01:20:24 INFO]: Environment: authHost='https://authserver.mojang.com', accountsHost='https://api.mojang.com', sessionHost='https://sessionserver.mojang.com', servicesHost='https://api.minecraftservices.com', name='PROD'
# [01:20:25 INFO]: [CustomCrafting] Loading Recipes & Items
# [01:20:25 INFO]: [CustomCrafting] - - - - [Local Storage] - - - -
# [01:20:25 INFO]: [CustomCrafting] [LOCAL] Using 4 threads
# [01:20:25 INFO]: [CustomCrafting] [LOCAL] Looking through data folder...
# [01:20:25 INFO]: [CustomCrafting] [LOCAL] Loading Items
# [01:20:25 INFO]: [CustomCrafting] [LOCAL] Loading Recipes
# [01:20:25 ERROR]: Could not find parent org/bukkit/inventory/CraftingRecipe for class org/bukkit/inventory/ShapedRecipe in classloader jdk.internal.loader.ClassLoaders$AppClassLoader@4f2410ac on thread Thread[#86,ForkJoinPool-3-worker-2,5,SERVER]
# [01:20:25 ERROR]: An error occurred building event handler
# java.lang.ClassNotFoundException: org.bukkit.inventory.CraftingRecipe
# 	at jdk.internal.loader.BuiltinClassLoader.loadClass(BuiltinClassLoader.java:641) ~[?:?]
# 	at jdk.internal.loader.ClassLoaders$AppClassLoader.loadClass(ClassLoaders.java:188) ~[?:?]
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:526) ~[?:?]
# 	at net.minecraftforge.eventbus.EventSubclassTransformer.buildEvents(EventSubclassTransformer.java:97) ~[eventbus-6.0.5.jar:?]
# 	at net.minecraftforge.eventbus.EventSubclassTransformer.transform(EventSubclassTransformer.java:48) ~[eventbus-6.0.5.jar:?]
# 	at net.minecraftforge.eventbus.EventBusEngine.processClass(EventBusEngine.java:26) ~[eventbus-6.0.5.jar:?]
# 	at net.minecraftforge.eventbus.service.ModLauncherService.processClassWithFlags(ModLauncherService.java:32) ~[eventbus-6.0.5.jar:6.0.5+0+master.c510e2cc]
# 	at cpw.mods.modlauncher.LaunchPluginHandler.offerClassNodeToPlugins(LaunchPluginHandler.java:88) ~[modlauncher-10.0.9.jar:?]
# 	at cpw.mods.modlauncher.ClassTransformer.transform(ClassTransformer.java:120) ~[modlauncher-10.0.9.jar:?]
# 	at cpw.mods.modlauncher.TransformingClassLoader.maybeTransformClassBytes(TransformingClassLoader.java:50) ~[modlauncher-10.0.9.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.readerToClass(ModuleClassLoader.java:121) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.lambda$findClass$15(ModuleClassLoader.java:257) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.loadFromModule(ModuleClassLoader.java:267) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.findClass(ModuleClassLoader.java:257) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.loadClass(ModuleClassLoader.java:144) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:580) ~[?:?]
# 	at org.bukkit.plugin.java.PluginClassLoader.loadClass0(PluginClassLoader.java:143) ~[?:?]
# 	at org.bukkit.plugin.java.PluginClassLoader.loadClass(PluginClassLoader.java:138) ~[?:?]
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:526) ~[?:?]
# 	at java.lang.Class.forName0(Native Method) ~[?:?]
# 	at java.lang.Class.forName(Class.java:534) ~[?:?]
# 	at java.lang.Class.forName(Class.java:513) ~[?:?]
# 	at sun.reflect.generics.factory.CoreReflectionFactory.makeNamedType(CoreReflectionFactory.java:114) ~[?:?]
# 	at sun.reflect.generics.visitor.Reifier.visitClassTypeSignature(Reifier.java:125) ~[?:?]
# 	at sun.reflect.generics.tree.ClassTypeSignature.accept(ClassTypeSignature.java:49) ~[?:?]
# 	at sun.reflect.generics.visitor.Reifier.reifyTypeArguments(Reifier.java:68) ~[?:?]
# 	at sun.reflect.generics.visitor.Reifier.visitClassTypeSignature(Reifier.java:138) ~[?:?]
# 	at sun.reflect.generics.tree.ClassTypeSignature.accept(ClassTypeSignature.java:49) ~[?:?]
# 	at sun.reflect.generics.repository.ClassRepository.computeSuperInterfaces(ClassRepository.java:117) ~[?:?]
# 	at sun.reflect.generics.repository.ClassRepository.getSuperInterfaces(ClassRepository.java:95) ~[?:?]
# 	at java.lang.Class.getGenericInterfaces(Class.java:1296) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.util.ClassUtil.getGenericInterfaces(ClassUtil.java:1310) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.type.TypeFactory._resolveSuperInterfaces(TypeFactory.java:1521) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.type.TypeFactory._fromClass(TypeFactory.java:1476) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.type.TypeFactory.constructSpecializedType(TypeFactory.java:488) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.DeserializationContext.constructSpecializedType(DeserializationContext.java:303) ~[?:?]
# 	at me.wolfyscript.customcrafting.recipes.RecipeTypeIdResolver.typeFromId(RecipeTypeIdResolver.java:66) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.jsontype.impl.TypeDeserializerBase._findDeserializer(TypeDeserializerBase.java:159) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.jsontype.impl.AsPropertyTypeDeserializer._deserializeTypedForId(AsPropertyTypeDeserializer.java:125) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.jsontype.impl.AsPropertyTypeDeserializer.deserializeTypedFromObject(AsPropertyTypeDeserializer.java:110) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.deser.AbstractDeserializer.deserializeWithType(AbstractDeserializer.java:263) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.deser.impl.TypeWrappedDeserializer.deserialize(TypeWrappedDeserializer.java:74) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.deser.DefaultDeserializationContext.readRootValue(DefaultDeserializationContext.java:323) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.ObjectReader._bindAndClose(ObjectReader.java:2051) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.ObjectReader.readValue(ObjectReader.java:1599) ~[?:?]
# 	at me.wolfyscript.customcrafting.handlers.LocalStorageLoader$NewDataLoader.lambda$loadRecipesInNamespace$2(LocalStorageLoader.java:483) ~[?:?]
# 	at java.util.concurrent.ForkJoinTask$RunnableExecuteAction.exec(ForkJoinTask.java:1423) [?:?]
# 	at java.util.concurrent.ForkJoinTask.doExec(ForkJoinTask.java:387) [?:?]
# 	at java.util.concurrent.ForkJoinPool$WorkQueue.topLevelExec(ForkJoinPool.java:1312) [?:?]
# 	at java.util.concurrent.ForkJoinPool.scan(ForkJoinPool.java:1843) [?:?]
# 	at java.util.concurrent.ForkJoinPool.runWorker(ForkJoinPool.java:1808) [?:?]
# 	at java.util.concurrent.ForkJoinWorkerThread.run(ForkJoinWorkerThread.java:188) [?:?]
# [01:20:25 ERROR]: Could not find parent org/bukkit/inventory/CraftingRecipe for class org/bukkit/inventory/ShapelessRecipe in classloader jdk.internal.loader.ClassLoaders$AppClassLoader@4f2410ac on thread Thread[#85,ForkJoinPool-3-worker-1,5,SERVER]
# [01:20:25 ERROR]: An error occurred building event handler
# java.lang.ClassNotFoundException: org.bukkit.inventory.CraftingRecipe
# 	at jdk.internal.loader.BuiltinClassLoader.loadClass(BuiltinClassLoader.java:641) ~[?:?]
# 	at jdk.internal.loader.ClassLoaders$AppClassLoader.loadClass(ClassLoaders.java:188) ~[?:?]
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:526) ~[?:?]
# 	at net.minecraftforge.eventbus.EventSubclassTransformer.buildEvents(EventSubclassTransformer.java:97) ~[eventbus-6.0.5.jar:?]
# 	at net.minecraftforge.eventbus.EventSubclassTransformer.transform(EventSubclassTransformer.java:48) ~[eventbus-6.0.5.jar:?]
# 	at net.minecraftforge.eventbus.EventBusEngine.processClass(EventBusEngine.java:26) ~[eventbus-6.0.5.jar:?]
# 	at net.minecraftforge.eventbus.service.ModLauncherService.processClassWithFlags(ModLauncherService.java:32) ~[eventbus-6.0.5.jar:6.0.5+0+master.c510e2cc]
# 	at cpw.mods.modlauncher.LaunchPluginHandler.offerClassNodeToPlugins(LaunchPluginHandler.java:88) ~[modlauncher-10.0.9.jar:?]
# 	at cpw.mods.modlauncher.ClassTransformer.transform(ClassTransformer.java:120) ~[modlauncher-10.0.9.jar:?]
# 	at cpw.mods.modlauncher.TransformingClassLoader.maybeTransformClassBytes(TransformingClassLoader.java:50) ~[modlauncher-10.0.9.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.readerToClass(ModuleClassLoader.java:121) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.lambda$findClass$15(ModuleClassLoader.java:257) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.loadFromModule(ModuleClassLoader.java:267) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.findClass(ModuleClassLoader.java:257) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.loadClass(ModuleClassLoader.java:144) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:580) ~[?:?]
# 	at org.bukkit.plugin.java.PluginClassLoader.loadClass0(PluginClassLoader.java:143) ~[?:?]
# 	at org.bukkit.plugin.java.PluginClassLoader.loadClass(PluginClassLoader.java:138) ~[?:?]
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:526) ~[?:?]
# 	at java.lang.Class.forName0(Native Method) ~[?:?]
# 	at java.lang.Class.forName(Class.java:534) ~[?:?]
# 	at java.lang.Class.forName(Class.java:513) ~[?:?]
# 	at sun.reflect.generics.factory.CoreReflectionFactory.makeNamedType(CoreReflectionFactory.java:114) ~[?:?]
# 	at sun.reflect.generics.visitor.Reifier.visitClassTypeSignature(Reifier.java:125) ~[?:?]
# 	at sun.reflect.generics.tree.ClassTypeSignature.accept(ClassTypeSignature.java:49) ~[?:?]
# 	at sun.reflect.generics.visitor.Reifier.reifyTypeArguments(Reifier.java:68) ~[?:?]
# 	at sun.reflect.generics.visitor.Reifier.visitClassTypeSignature(Reifier.java:138) ~[?:?]
# 	at sun.reflect.generics.tree.ClassTypeSignature.accept(ClassTypeSignature.java:49) ~[?:?]
# 	at sun.reflect.generics.repository.ClassRepository.computeSuperInterfaces(ClassRepository.java:117) ~[?:?]
# 	at sun.reflect.generics.repository.ClassRepository.getSuperInterfaces(ClassRepository.java:95) ~[?:?]
# 	at java.lang.Class.getGenericInterfaces(Class.java:1296) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.util.ClassUtil.getGenericInterfaces(ClassUtil.java:1310) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.type.TypeFactory._resolveSuperInterfaces(TypeFactory.java:1521) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.type.TypeFactory._fromClass(TypeFactory.java:1476) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.type.TypeFactory.constructSpecializedType(TypeFactory.java:488) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.DeserializationContext.constructSpecializedType(DeserializationContext.java:303) ~[?:?]
# 	at me.wolfyscript.customcrafting.recipes.RecipeTypeIdResolver.typeFromId(RecipeTypeIdResolver.java:66) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.jsontype.impl.TypeDeserializerBase._findDeserializer(TypeDeserializerBase.java:159) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.jsontype.impl.AsPropertyTypeDeserializer._deserializeTypedForId(AsPropertyTypeDeserializer.java:125) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.jsontype.impl.AsPropertyTypeDeserializer.deserializeTypedFromObject(AsPropertyTypeDeserializer.java:110) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.deser.AbstractDeserializer.deserializeWithType(AbstractDeserializer.java:263) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.deser.impl.TypeWrappedDeserializer.deserialize(TypeWrappedDeserializer.java:74) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.deser.DefaultDeserializationContext.readRootValue(DefaultDeserializationContext.java:323) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.ObjectReader._bindAndClose(ObjectReader.java:2051) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.ObjectReader.readValue(ObjectReader.java:1599) ~[?:?]
# 	at me.wolfyscript.customcrafting.handlers.LocalStorageLoader$NewDataLoader.lambda$loadRecipesInNamespace$2(LocalStorageLoader.java:483) ~[?:?]
# 	at java.util.concurrent.ForkJoinTask$RunnableExecuteAction.exec(ForkJoinTask.java:1423) [?:?]
# 	at java.util.concurrent.ForkJoinTask.doExec(ForkJoinTask.java:387) [?:?]
# 	at java.util.concurrent.ForkJoinPool$WorkQueue.topLevelExec(ForkJoinPool.java:1312) [?:?]
# 	at java.util.concurrent.ForkJoinPool.scan(ForkJoinPool.java:1843) [?:?]
# 	at java.util.concurrent.ForkJoinPool.runWorker(ForkJoinPool.java:1808) [?:?]
# 	at java.util.concurrent.ForkJoinWorkerThread.run(ForkJoinWorkerThread.java:188) [?:?]
# [01:20:25 INFO]: [CustomCrafting] [LOCAL] Loaded 6 recipes in 92ms
# [01:20:25 INFO]: [CustomCrafting] Indexing Recipe Book...
# [01:20:25 INFO]: [CustomCrafting] Indexed Recipe Book!
# [01:20:25 INFO]: [CustomCrafting] ------------------------------------------------------------------------
# [01:20:25 INFO]: [Mohist] Enabling Mohist v1.20.1
# [01:20:25 INFO]: Server permissions file permissions.yml is empty, ignoring it
# [01:20:25 INFO]: Done (17.095s)! For help, type "help"
# [01:20:25 INFO]: Successfully initialized permission handler forge:default_handler
# [01:20:25 INFO]: Forwarding forge permission[forge:default_handler] to bukkit[mohist:permission]
# [01:20:25 WARN]: [voicechat] Running in offline mode - Voice chat encryption is not secure!
# [01:20:25 INFO]: [voicechat] Voice chat server started at port 25565
# [01:20:25 INFO]: GlitchWorld ➤ No se ha encontrado una librería JDA, deberás instalar una en caso de querer utilizar un bot de Discord.
# [01:20:25 INFO]: Descarga aquí: https://www.spigotmc.org/resources/permadeath-%E2%98%A0%EF%B8%8F.112343/
# [01:20:25 INFO]: Si no puedes descargarlo allí, únete a este Discord y te daremos acceso al enlace: https://discord.gg/8evPbuxPke
# [01:20:25 INFO]: [11/04/2024] 01:20:25 [ERROR] Error al cargar el mundo del end, esto hará que el end no funcione como debe.
#
# [01:20:25 INFO]: [11/04/2024] 01:20:25 [ERROR] Abre el archivo config.yml y establece el mundo del end en la opción: EndWorld
#
# [01:20:25 INFO]: [11/04/2024] 01:20:25 [INFO] El plugin utilizará el mundo DIM1 como mundo del End.
#
# [01:20:25 INFO]: ------------------------------------------
# [01:20:25 INFO]:              PERMADEATH
# [01:20:25 INFO]:      - Versión: 1.3
# [01:20:25 INFO]:      - Versión del Servidor: v1.20
# [01:20:25 INFO]: ------------------------------------------
# [01:20:25 INFO]:  >> INFORME DE ESTADO
# [01:20:25 INFO]: > Estado de mundos: Overworld: world End: world
# [01:20:25 INFO]:     > End: world
# [01:20:25 INFO]:     > Overworld: world
# [01:20:25 INFO]: > Estado de Compatibilidad: Compatible
# [01:20:25 INFO]: > Software: SpigotMC (Compatible)
# [01:20:25 INFO]: > Cambios:
# [01:20:25 INFO]: >   Días disponibles: 1-60
# [01:20:25 INFO]: [SkinsRestorer] ----------------------------------------------
# [01:20:25 INFO]: [SkinsRestorer]     +==================+
# [01:20:25 INFO]: [SkinsRestorer]     |   SkinsRestorer  |
# [01:20:25 INFO]: [SkinsRestorer]     |------------------|
# [01:20:25 INFO]: [SkinsRestorer]     |  Standalone Mode |
# [01:20:25 INFO]: [SkinsRestorer]     +==================+
# [01:20:25 INFO]: [SkinsRestorer] ----------------------------------------------
# [01:20:25 INFO]: [SkinsRestorer]     Version: 15.0.8
# [01:20:25 INFO]: [SkinsRestorer]     Commit: 8b54a2c
# [01:20:25 INFO]: [SkinsRestorer]     This is the latest version!
# [01:20:25 INFO]: [SkinsRestorer] ----------------------------------------------
# [01:20:26 INFO]: GlitchWorld ➤ Versión del plugin: Versión más reciente instalada.
# [01:20:46 INFO]: Mr_PanckeisXD se ha unido al glitch.
# [01:20:47 INFO]: Mr_PanckeisXD[/127.0.0.1:43148] logged in with entity id 135 at ([world]0.17473918623798515, 56.500262571715666, 8.455626392697486)
# [01:20:48 INFO]: [voicechat] Received secret request of [ADMIN] Mr_PanckeisXD (18)
# [01:20:48 INFO]: [voicechat] Sent secret to [ADMIN] Mr_PanckeisXD
# [01:21:50 INFO]: Mr_PanckeisXD issued server command: /gamemode survival
# [01:21:50 INFO]: [[ADMIN] Mr_PanckeisXD: Set own game mode to Survival Mode]
# [01:21:51 INFO]: Set the weather to rain & thunder
# [01:21:51 INFO]: Mr_PanckeisXD ha muerto y ahora descanza en paz.
# [01:21:51 INFO]: Este es el comienzo del sufrimiento eterno de Mr_PanckeisXD. ¡HA SIDO GLITCHEADO!
# [01:21:51 INFO]: X: 7 || Y: 52 || Z: 7
# [01:21:51 INFO]: [ADMIN] Mr_PanckeisXD was slain by Zombie
# [01:21:56 INFO]: ¡Comienza el GLITCH Train con duración de 3 horas!
# [01:22:02 INFO]: Mr_PanckeisXD issued server command: /gamemode creative
# [01:22:02 INFO]: [[ADMIN] Mr_PanckeisXD: Set own game mode to Creative Mode]
# [01:22:22 INFO]: Mr_PanckeisXD issued server command: /weather clear
# [01:22:22 INFO]: La tormenta glitcheada ha llegado a su fin.
# [01:22:22 INFO]: [[ADMIN] Mr_PanckeisXD: Set the weather to clear]
# [01:25:29 INFO]: Mr_PanckeisXD issued server command: /pdc afk
# [01:25:45 INFO]: Mr_PanckeisXD issued server command: /pdc reload
# [01:25:45 INFO]: [11/04/2024] 01:25:45 [ERROR] Error al cargar el mundo del end, esto hará que el end no funcione como debe.
#
# [01:25:45 INFO]: [11/04/2024] 01:25:45 [ERROR] Abre el archivo config.yml y establece el mundo del end en la opción: EndWorld
#
# [01:25:45 INFO]: [11/04/2024] 01:25:45 [INFO] El plugin utilizará el mundo DIM1 como mundo del End.
#
# [01:25:51 INFO]: Mr_PanckeisXD issued server command: /kill
# [01:25:51 INFO]: Set the weather to rain & thunder
# [01:25:51 INFO]: Mr_PanckeisXD ha muerto y ahora descanza en paz.
# [01:25:51 INFO]: Este es el comienzo del sufrimiento eterno de Mr_PanckeisXD. ¡HA SIDO GLITCHEADO!
# [01:25:51 INFO]: X: 4 || Y: 52 || Z: 8
# [01:25:51 INFO]: [ADMIN] Mr_PanckeisXD was killed
# [01:25:51 INFO]: [[ADMIN] Mr_PanckeisXD: Killed [ADMIN] Mr_PanckeisXD]
# [01:25:56 INFO]: ¡Comienza el GLITCH Train con duración de 3 horas!
# [01:26:00 INFO]: Mr_PanckeisXD issued server command: /gamemode creative
# [01:26:00 INFO]: [[ADMIN] Mr_PanckeisXD: Set own game mode to Creative Mode]
# [01:26:40 INFO]: Mr_PanckeisXD issued server command: /enchant Mr_PanckeisXD minecraft:protection
# [01:26:40 INFO]: [[ADMIN] Mr_PanckeisXD: Applied enchantment Protection I to [ADMIN] Mr_PanckeisXD's item]
# [01:26:42 INFO]: Mr_PanckeisXD issued server command: /enchant Mr_PanckeisXD minecraft:protection 4
# [01:26:49 INFO]: Mr_PanckeisXD issued server command: /enchant Mr_PanckeisXD minecraft:protection 4
# [01:26:49 INFO]: [[ADMIN] Mr_PanckeisXD: Applied enchantment Protection IV to [ADMIN] Mr_PanckeisXD's item]
# [01:26:51 INFO]: Mr_PanckeisXD issued server command: /enchant Mr_PanckeisXD minecraft:protection 4
# [01:26:51 INFO]: [[ADMIN] Mr_PanckeisXD: Applied enchantment Protection IV to [ADMIN] Mr_PanckeisXD's item]
# [01:26:52 INFO]: Mr_PanckeisXD issued server command: /enchant Mr_PanckeisXD minecraft:protection 4
# [01:26:52 INFO]: [[ADMIN] Mr_PanckeisXD: Applied enchantment Protection IV to [ADMIN] Mr_PanckeisXD's item]
# [01:26:56 INFO]: Mr_PanckeisXD issued server command: /enchant Mr_PanckeisXD minecraft:protection 4
# [01:26:56 INFO]: [[ADMIN] Mr_PanckeisXD: Applied enchantment Protection IV to [ADMIN] Mr_PanckeisXD's item]
# [01:27:13 INFO]: Mr_PanckeisXD issued server command: /gamemode survival
# [01:27:13 INFO]: [[ADMIN] Mr_PanckeisXD: Set own game mode to Survival Mode]
# [01:27:40 INFO]: [INFO] La probabilidad del tótem se encuentra desactivada para el día: 3
# [01:28:08 INFO]: [INFO] La probabilidad del tótem se encuentra desactivada para el día: 3
# [01:28:44 INFO]: [INFO] La probabilidad del tótem se encuentra desactivada para el día: 3
# [01:29:16 INFO]: Mr_PanckeisXD issued server command: /gamemode creative
# [01:29:16 INFO]: [[ADMIN] Mr_PanckeisXD: Set own game mode to Creative Mode]
# [01:29:30 INFO]: Mr_PanckeisXD issued server command: /gamemode survival
# [01:29:30 INFO]: [[ADMIN] Mr_PanckeisXD: Set own game mode to Survival Mode]
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [01:29:57 INFO]: [INFO] La probabilidad del tótem se encuentra desactivada para el día: 3
# [01:30:15 INFO]: [INFO] La probabilidad del tótem se encuentra desactivada para el día: 3
# [01:30:28 INFO]: [INFO] La probabilidad del tótem se encuentra desactivada para el día: 3
# [01:30:32 INFO]: Set the weather to rain & thunder
# [01:30:32 INFO]: Mr_PanckeisXD ha muerto y ahora descanza en paz.
# [01:30:32 INFO]: Este es el comienzo del sufrimiento eterno de Mr_PanckeisXD. ¡HA SIDO GLITCHEADO!
# [01:30:32 INFO]: X: -3 || Y: 52 || Z: 0
# [01:30:32 INFO]: [ADMIN] Mr_PanckeisXD was slain by Zombie
# [01:30:36 INFO]: ¡Comienza el GLITCH Train con duración de 3 horas!
# [01:30:43 INFO]: Mr_PanckeisXD issued server command: /pdc dias 1
# [01:30:48 INFO]: Mr_PanckeisXD issued server command: /weather clear
# [01:30:48 INFO]: La tormenta glitcheada ha llegado a su fin.
# [01:30:48 INFO]: [[ADMIN] Mr_PanckeisXD: Set the weather to clear]
# [01:30:52 INFO]: Mr_PanckeisXD issued server command: /gamemode creative
# [01:30:52 INFO]: [[ADMIN] Mr_PanckeisXD: Set own game mode to Creative Mode]
# [01:31:25 INFO]: Mr_PanckeisXD issued server command: /enchant Mr_PanckeisXD minecraft:protection 4
# [01:31:25 INFO]: [[ADMIN] Mr_PanckeisXD: Applied enchantment Protection IV to [ADMIN] Mr_PanckeisXD's item]
# [01:31:33 INFO]: Mr_PanckeisXD issued server command: /enchant Mr_PanckeisXD minecraft:mending
# [01:31:33 INFO]: [[ADMIN] Mr_PanckeisXD: Applied enchantment Mending to [ADMIN] Mr_PanckeisXD's item]
# [01:31:35 INFO]: Mr_PanckeisXD issued server command: /enchant Mr_PanckeisXD minecraft:mending
# [01:31:35 INFO]: [[ADMIN] Mr_PanckeisXD: Applied enchantment Mending to [ADMIN] Mr_PanckeisXD's item]
# [01:31:36 INFO]: Mr_PanckeisXD issued server command: /enchant Mr_PanckeisXD minecraft:mending
# [01:31:36 INFO]: [[ADMIN] Mr_PanckeisXD: Applied enchantment Mending to [ADMIN] Mr_PanckeisXD's item]
# [01:31:38 INFO]: Mr_PanckeisXD issued server command: /enchant Mr_PanckeisXD minecraft:mending
# [01:31:38 INFO]: [[ADMIN] Mr_PanckeisXD: Applied enchantment Mending to [ADMIN] Mr_PanckeisXD's item]
# [01:31:43 INFO]: Mr_PanckeisXD issued server command: /enchant Mr_PanckeisXD minecraft:unbreaking 3
# [01:31:43 INFO]: [[ADMIN] Mr_PanckeisXD: Applied enchantment Unbreaking III to [ADMIN] Mr_PanckeisXD's item]
# [01:31:45 INFO]: Mr_PanckeisXD issued server command: /enchant Mr_PanckeisXD minecraft:unbreaking 3
# [01:31:45 INFO]: [[ADMIN] Mr_PanckeisXD: Applied enchantment Unbreaking III to [ADMIN] Mr_PanckeisXD's item]
# [01:31:46 INFO]: Mr_PanckeisXD issued server command: /enchant Mr_PanckeisXD minecraft:unbreaking 3
# [01:31:46 INFO]: [[ADMIN] Mr_PanckeisXD: Applied enchantment Unbreaking III to [ADMIN] Mr_PanckeisXD's item]
# [01:31:48 INFO]: Mr_PanckeisXD issued server command: /enchant Mr_PanckeisXD minecraft:unbreaking 3
# [01:31:48 INFO]: [[ADMIN] Mr_PanckeisXD: Applied enchantment Unbreaking III to [ADMIN] Mr_PanckeisXD's item]
# [01:32:27 INFO]: Mr_PanckeisXD issued server command: /gamemode survival
# [01:32:27 INFO]: [[ADMIN] Mr_PanckeisXD: Set own game mode to Survival Mode]
# [01:32:32 INFO]: Mr_PanckeisXD issued server command: /gamemode creative
# [01:32:32 INFO]: [[ADMIN] Mr_PanckeisXD: Set own game mode to Creative Mode]
# [01:32:42 INFO]: Mr_PanckeisXD issued server command: /gamemode survival
# [01:32:42 INFO]: [[ADMIN] Mr_PanckeisXD: Set own game mode to Survival Mode]
# [01:32:54 INFO]: Set the weather to rain & thunder
# [01:32:54 INFO]: Mr_PanckeisXD ha muerto y ahora descanza en paz.
# [01:32:54 INFO]: Este es el comienzo del sufrimiento eterno de Mr_PanckeisXD. ¡HA SIDO GLITCHEADO!
# [01:32:54 INFO]: X: -6 || Y: 52 || Z: 0
# [01:32:54 INFO]: [ADMIN] Mr_PanckeisXD was slain by Zombie
# [01:32:59 INFO]: ¡Comienza el GLITCH Train con duración de 3 horas!
# [01:33:02 INFO]: Mr_PanckeisXD issued server command: /weather clear
# [01:33:02 INFO]: La tormenta glitcheada ha llegado a su fin.
# [01:33:02 INFO]: [[ADMIN] Mr_PanckeisXD: Set the weather to clear]
# [01:33:06 INFO]: Mr_PanckeisXD issued server command: /gamemode creative
# [01:33:06 INFO]: [[ADMIN] Mr_PanckeisXD: Set own game mode to Creative Mode]
# [01:33:13 INFO]: Mr_PanckeisXD issued server command: /gamemode survival
# [01:33:13 INFO]: [[ADMIN] Mr_PanckeisXD: Set own game mode to Survival Mode]
# [01:33:20 INFO]: [INFO] La probabilidad del tótem se encuentra desactivada para el día: 3
# [01:33:23 INFO]: [INFO] La probabilidad del tótem se encuentra desactivada para el día: 3
# [01:33:36 INFO]: [INFO] La probabilidad del tótem se encuentra desactivada para el día: 3
# [01:34:39 INFO]: [INFO] La probabilidad del tótem se encuentra desactivada para el día: 3
# [01:34:52 INFO]: [INFO] La probabilidad del tótem se encuentra desactivada para el día: 3
# [01:35:00 INFO]: Set the weather to rain & thunder
# [01:35:00 INFO]: Mr_PanckeisXD ha muerto y ahora descanza en paz.
# [01:35:00 INFO]: Este es el comienzo del sufrimiento eterno de Mr_PanckeisXD. ¡HA SIDO GLITCHEADO!
# [01:35:00 INFO]: X: 11 || Y: 52 || Z: 14
# [01:35:00 INFO]: [ADMIN] Mr_PanckeisXD was slain by Zombie
# [01:35:05 INFO]: ¡Comienza el GLITCH Train con duración de 3 horas!
# [01:35:08 INFO]: Mr_PanckeisXD issued server command: /weather clear
# [01:35:08 INFO]: La tormenta glitcheada ha llegado a su fin.
# [01:35:08 INFO]: [[ADMIN] Mr_PanckeisXD: Set the weather to clear]
# [01:35:13 INFO]: Mr_PanckeisXD issued server command: /gamemode creative
# [01:35:13 INFO]: [[ADMIN] Mr_PanckeisXD: Set own game mode to Creative Mode]
# [01:35:36 INFO]: Mr_PanckeisXD issued server command: /kill @e[type=zombie]
# [01:35:36 INFO]: [[ADMIN] Mr_PanckeisXD: Killed 18 entities]
# [01:38:29 INFO]: Mr_PanckeisXD issued server command: /kill @e[type=zombie]
# [01:38:29 INFO]: [[ADMIN] Mr_PanckeisXD: Killed 8 entities]
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [01:40:13 INFO]: Mr_PanckeisXD lost connection: Disconnected
# [01:40:13 INFO]: [voicechat] Disconnecting client [ADMIN] Mr_PanckeisXD
# [01:40:13 INFO]: Mr_PanckeisXD ha abandonado el glitch.
# [01:40:39 INFO]: Mr_PanckeisXD se ha unido al glitch.
# [01:40:39 INFO]: Mr_PanckeisXD[/127.0.0.1:39946] logged in with entity id 1800 at ([world]4.271523304400291, 59.15382263578705, 15.401201459705439)
# [01:40:39 INFO]: [voicechat] Received secret request of [ADMIN] Mr_PanckeisXD (18)
# [01:40:39 INFO]: [voicechat] Sent secret to [ADMIN] Mr_PanckeisXD
# [01:43:45 INFO]: iYooyo se ha unido al glitch.
# [01:43:45 INFO]: iYooyo[/127.0.0.1:41020] logged in with entity id 2003 at ([world]2.8703663040193135, 105.0, 0.47243738508313765)
# [01:43:46 INFO]: [voicechat] Received secret request of [ADMIN] iYooyo (18)
# [01:43:46 INFO]: [voicechat] Sent secret to [ADMIN] iYooyo
# [01:45:20 INFO]: <iYooyo> vas a poner
# [01:45:24 INFO]: <iYooyo> el /login despues?
# [01:45:30 INFO]: <Mr_PanckeisXD> si XD
# [01:45:42 INFO]: <iYooyo> te parece si hago una mini muralla en el spawn?
# [01:45:46 INFO]: <iYooyo> o más al aire libre
# [01:46:04 INFO]: <Mr_PanckeisXD> mas al aire libre
# [01:46:05 INFO]: <Mr_PanckeisXD> mejor mira
# [01:46:06 INFO]: <iYooyo> oka
# [01:46:08 INFO]: Mr_PanckeisXD issued server command: /tp iYooyo
# [01:46:08 INFO]: [[ADMIN] Mr_PanckeisXD: Teleported [ADMIN] Mr_PanckeisXD to [ADMIN] iYooyo]
# [01:46:12 INFO]: <iYooyo> la hago corte
# [01:46:13 INFO]: <iYooyo> la de
# [01:46:19 INFO]: <iYooyo> clash of clans
# [01:46:23 INFO]: <Mr_PanckeisXD> XD
# [01:46:31 INFO]: <Mr_PanckeisXD> mejor dame el comando de /rg
# [01:46:35 INFO]: <Mr_PanckeisXD> o como hacer eso
# [01:46:40 INFO]: <iYooyo> yo lo hago chill
# [01:47:00 INFO]: <iYooyo> pero lo hago cuando ya este terminado
# [01:47:05 INFO]: <Mr_PanckeisXD> ok
# [01:47:05 INFO]: <iYooyo> pq por ahi lo hago corto
# [01:47:09 INFO]: <iYooyo> y necesito más espaciop
# [01:47:10 INFO]: <Mr_PanckeisXD> ok
# [01:48:18 INFO]: Mr_PanckeisXD issued server command: /gamemode survival
# [01:48:18 INFO]: [[ADMIN] Mr_PanckeisXD: Set own game mode to Survival Mode]
# [01:48:20 INFO]: Mr_PanckeisXD issued server command: /gamemode creative
# [01:48:20 INFO]: [[ADMIN] Mr_PanckeisXD: Set own game mode to Creative Mode]
# [01:48:25 INFO]: Mr_PanckeisXD issued server command: /gamemode survival
# [01:48:25 INFO]: [[ADMIN] Mr_PanckeisXD: Set own game mode to Survival Mode]
# [01:48:33 INFO]: Mr_PanckeisXD issued server command: /gamemode creative
# [01:48:33 INFO]: [[ADMIN] Mr_PanckeisXD: Set own game mode to Creative Mode]
# [01:48:36 INFO]: iYooyo issued server command: //copy
# [01:48:37 INFO]: Mr_PanckeisXD issued server command: /gamemode survival
# [01:48:37 INFO]: [[ADMIN] Mr_PanckeisXD: Set own game mode to Survival Mode]
# [01:48:38 INFO]: Mr_PanckeisXD issued server command: /gamemode creative
# [01:48:38 INFO]: [[ADMIN] Mr_PanckeisXD: Set own game mode to Creative Mode]
# [01:48:38 INFO]: iYooyo issued server command: //cut
# [01:48:47 INFO]: Mr_PanckeisXD issued server command: /gamemode survival
# [01:48:47 INFO]: [[ADMIN] Mr_PanckeisXD: Set own game mode to Survival Mode]
# [01:48:48 INFO]: iYooyo issued server command: //rotate 90
# [01:48:50 INFO]: iYooyo issued server command: //paste
# [01:49:00 INFO]: iYooyo issued server command: //undo
# [01:49:00 INFO]: iYooyo issued server command: //undo
# [01:49:03 INFO]: Mr_PanckeisXD issued server command: /gamemode creative
# [01:49:03 INFO]: [[ADMIN] Mr_PanckeisXD: Set own game mode to Creative Mode]
# [01:49:04 INFO]: iYooyo issued server command: //copy
# [01:49:13 INFO]: iYooyo issued server command: //paste
# [01:49:17 INFO]: iYooyo issued server command: //undo
# [01:49:20 INFO]: iYooyo issued server command: //rotate 90
# [01:49:21 INFO]: iYooyo issued server command: //paste
# [01:49:31 INFO]: iYooyo issued server command: //cut
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [01:50:00 INFO]: Mr_PanckeisXD issued server command: /gamemode survival
# [01:50:00 INFO]: [[ADMIN] Mr_PanckeisXD: Set own game mode to Survival Mode]
# [01:50:03 INFO]: Mr_PanckeisXD issued server command: /gamemode creative
# [01:50:03 INFO]: [[ADMIN] Mr_PanckeisXD: Set own game mode to Creative Mode]
# [01:50:13 INFO]: Mr_PanckeisXD issued server command: /gamemode survival
# [01:50:13 INFO]: [[ADMIN] Mr_PanckeisXD: Set own game mode to Survival Mode]
# [01:50:15 INFO]: <iYooyo> tenes los huevos
# [01:50:17 INFO]: <iYooyo> del banco
# [01:50:20 INFO]: <iYooyo> y
# [01:50:21 INFO]: <Mr_PanckeisXD> no
# [01:50:23 INFO]: <Mr_PanckeisXD> esperame
# [01:50:24 INFO]: <iYooyo> del de comida?
# [01:50:26 INFO]: <Mr_PanckeisXD> ya los pongo
# [01:50:30 INFO]: <iYooyo> cuando puedas traemelos
# [01:50:38 INFO]: <Mr_PanckeisXD> mejor cuando hagas sus lugares te los paso
# [01:50:42 INFO]: <iYooyo> oka
# [01:50:44 INFO]: Mr_PanckeisXD issued server command: /gamemode creative
# [01:50:44 INFO]: [[ADMIN] Mr_PanckeisXD: Set own game mode to Creative Mode]
# [01:50:46 INFO]: <iYooyo> pero puedo matarlos?
# [01:50:47 INFO]: Mr_PanckeisXD issued server command: /gamemode survival
# [01:50:47 INFO]: [[ADMIN] Mr_PanckeisXD: Set own game mode to Survival Mode]
# [01:50:50 INFO]: <iYooyo> corte tenes el hyevo?
# [01:50:50 INFO]: <Mr_PanckeisXD> no
# [01:50:54 INFO]: <Mr_PanckeisXD> si no se pierde XD
# [01:51:01 INFO]: Mr_PanckeisXD issued server command: /gamemode creative
# [01:51:01 INFO]: [[ADMIN] Mr_PanckeisXD: Set own game mode to Creative Mode]
# [01:51:01 INFO]: <iYooyo> ah igual
# [01:51:03 INFO]: Mr_PanckeisXD issued server command: /gamemode survival
# [01:51:03 INFO]: [[ADMIN] Mr_PanckeisXD: Set own game mode to Survival Mode]
# [01:51:03 INFO]: <iYooyo> les hago tp
# [01:51:08 INFO]: <Mr_PanckeisXD> ok
# [01:51:12 INFO]: Mr_PanckeisXD issued server command: /gamemode creative
# [01:51:12 INFO]: [[ADMIN] Mr_PanckeisXD: Set own game mode to Creative Mode]
# [01:53:34 INFO]: <iYooyo> a la mierda
# [01:54:07 WARN]: Player Mr_PanckeisXD just tried to change non-editable sign
# [01:55:05 INFO]: iYooyo issued server command: /particle alexsmobs:dna ~ ~1 ~ 0.25 0.25 0.25 0.05 25 force
# [01:55:05 INFO]: [[ADMIN] iYooyo: Displaying particle alexsmobs:dna]
# [01:55:07 INFO]: <Mr_PanckeisXD> y yo
# [01:55:11 INFO]: iYooyo issued server command: /particle alexsmobs:dna ~5 ~1 ~ 0.25 0.25 0.25 0.05 25 force
# [01:55:11 INFO]: [[ADMIN] iYooyo: Displaying particle alexsmobs:dna]
# [01:55:17 INFO]: <Mr_PanckeisXD> que son estos bloques de comandos?
# [01:55:18 INFO]: iYooyo issued server command: /particle alexsmobs:dna ~ ~1 ~5 0.25 0.25 0.25 0.05 25 force
# [01:55:18 INFO]: [[ADMIN] iYooyo: Displaying particle alexsmobs:dna]
# ...
# [03:33:11 INFO]: ivelich350 issued server command: /give @p minecraft:player_head{SkullOwner:"<ivelich350"}
# [03:33:11 INFO]: [[ADMIN] ivelich350: Gave 1 [<ivelich350's Head] to [ADMIN] ivelich350]
# [03:33:14 INFO]: Mr_PanckeisXD issued server command: /time set 3000
# [03:33:14 INFO]: [[ADMIN] Mr_PanckeisXD: Set the time to 3000]
# [03:33:16 INFO]: iYooyo issued server command: //replacenear 25 stone 40%cracked_nether_bricks,40%nether_bricks,5%magma_block,15%red_nether_bricks
# [03:33:18 INFO]: ivelich350 issued server command: /give @p minecraft:player_head{SkullOwner:"ivelich350"}
# [03:33:18 INFO]: [[ADMIN] ivelich350: Gave 1 [ivelich350's Head] to [ADMIN] ivelich350]
# [03:33:22 INFO]: Mr_PanckeisXD issued server command: /time set 4000
# [03:33:22 INFO]: [[ADMIN] Mr_PanckeisXD: Set the time to 4000]
# [03:33:25 INFO]: iYooyo issued server command: //undo
# [03:33:28 INFO]: Mr_PanckeisXD issued server command: /time set 500000
# [03:33:28 INFO]: [[ADMIN] Mr_PanckeisXD: Set the time to 500000]
# [03:33:30 INFO]: Mr_PanckeisXD issued server command: /time set 50000
# [03:33:30 INFO]: [[ADMIN] Mr_PanckeisXD: Set the time to 50000]
# [03:33:32 INFO]: ivelich350 issued server command: /give @p minecraft:player_head{SkullOwner:"Mr_PanckeisXD"}
# [03:33:32 INFO]: [[ADMIN] ivelich350: Gave 1 [Mr_PanckeisXD's Head] to [ADMIN] ivelich350]
# [03:33:32 INFO]: iYooyo issued server command: //undo
# [03:33:36 INFO]: iYooyo issued server command: //brush sphere stone 3
# [03:33:38 INFO]: ivelich350 issued server command: /give @p minecraft:player_head{SkullOwner:"iyooyo"}
# [03:33:38 INFO]: [[ADMIN] ivelich350: Gave 1 [iyooyo's Head] to [ADMIN] ivelich350]
# [03:33:44 INFO]: ivelich350 issued server command: /give @p minecraft:player_head{SkullOwner:"iYooyo"}
# [03:33:44 INFO]: [[ADMIN] ivelich350: Gave 1 [iYooyo's Head] to [ADMIN] ivelich350]
# [03:33:51 INFO]: iYooyo issued server command: //brush smooth 3
# [03:33:58 INFO]: iYooyo issued server command: //brush sphere stone 3
# [03:34:01 INFO]: iYooyo issued server command: //brush smooth 3
# [03:34:07 INFO]: Mr_PanckeisXD issued server command: /skin clear
# [03:34:07 INFO]: <ivelich350> ./give @p minecraft:player_head{SkullOwner:"iYooyo"}
# [03:34:25 INFO]: ivelich350 issued server command: /tp iYooyo
# [03:34:25 INFO]: [[ADMIN] ivelich350: Teleported [ADMIN] ivelich350 to [ADMIN] iYooyo]
# [03:34:32 INFO]: ivelich350 issued server command: /gamemode spectator
# [03:34:32 INFO]: [[ADMIN] ivelich350: Set own game mode to Spectator Mode]
# [03:34:33 INFO]: iYooyo issued server command: //replacenear 25 stone 35%cracked_nether_bricks,35%nether_bricks,5%magma_block,10%red_nether_bricks,15%obsidian
# [03:34:42 INFO]: Mr_PanckeisXD issued server command: /give @p minecraft:player_head{SkulllOwner:"Mr_PanckeisXD"
# [03:34:45 INFO]: Mr_PanckeisXD issued server command: /give @p minecraft:player_head{SkulllOwner:"Mr_PanckeisXD"}
# [03:34:45 INFO]: [[ADMIN] Mr_PanckeisXD: Gave 1 [Player Head] to [ADMIN] Mr_PanckeisXD]
# [03:34:47 INFO]: ivelich350 issued server command: /gamemode creative
# [03:34:47 INFO]: [[ADMIN] ivelich350: Set own game mode to Creative Mode]
# [03:34:56 INFO]: iYooyo issued server command: //brush sphere stone 3
# [03:34:56 INFO]: <ivelich350> bueno muchachas me voy
# [03:34:58 INFO]: <ivelich350> X
# [03:34:59 INFO]: Mr_PanckeisXD issued server command: /give @p minecraft:player_head{SkulllOwner:"Mr_PanckeisXD"}
# [03:34:59 INFO]: [[ADMIN] Mr_PanckeisXD: Gave 1 [Player Head] to [ADMIN] Mr_PanckeisXD]
# [03:35:00 INFO]: <ivelich350> d
# [03:35:01 INFO]: Mr_PanckeisXD issued server command: /give @p minecraft:player_head{SkulllOwner:"Mr_PanckeisXD"}
# [03:35:01 INFO]: [[ADMIN] Mr_PanckeisXD: Gave 1 [Player Head] to [ADMIN] Mr_PanckeisXD]
# [03:35:01 INFO]: Mr_PanckeisXD issued server command: /give @p minecraft:player_head{SkulllOwner:"Mr_PanckeisXD"}
# [03:35:01 INFO]: [[ADMIN] Mr_PanckeisXD: Gave 1 [Player Head] to [ADMIN] Mr_PanckeisXD]
# [03:35:07 INFO]: <ivelich350> bueno muchachas me voy
# [03:35:08 INFO]: <ivelich350> d
# [03:35:10 INFO]: <ivelich350> X
# [03:35:12 INFO]: Mr_PanckeisXD issued server command: /give @p minecraft:player_head{SkulllOwner:"iyooyo"}
# [03:35:12 INFO]: [[ADMIN] Mr_PanckeisXD: Gave 1 [Player Head] to [ADMIN] Mr_PanckeisXD]
# [03:35:23 INFO]: ivelich350 issued server command: /give Mr_PanckeisXD minecraft:player_head{SkullOwner:"iYooyo"}
# [03:35:23 INFO]: [[ADMIN] ivelich350: Gave 1 [iYooyo's Head] to [ADMIN] Mr_PanckeisXD]
# [03:35:27 INFO]: Mr_PanckeisXD issued server command: /give @p minecraft:player_head{SkulllOwner:"iYooyo"}
# [03:35:27 INFO]: [[ADMIN] Mr_PanckeisXD: Gave 1 [Player Head] to [ADMIN] Mr_PanckeisXD]
# [03:35:30 INFO]: ivelich350 issued server command: /give Mr_PanckeisXD minecraft:player_head{SkullOwner:"ivelich350"}
# [03:35:30 INFO]: [[ADMIN] ivelich350: Gave 1 [ivelich350's Head] to [ADMIN] Mr_PanckeisXD]
# [03:35:40 INFO]: ivelich350 issued server command: /give Mr_PanckeisXD minecraft:player_head{SkullOwner:"Mr_PanckeisXD"}
# [03:35:40 INFO]: [[ADMIN] ivelich350: Gave 1 [Mr_PanckeisXD's Head] to [ADMIN] Mr_PanckeisXD]
# [03:35:40 INFO]: Mr_PanckeisXD issued server command: /tp ivelich350 Mr_PanckeisXD
# [03:35:40 INFO]: [[ADMIN] Mr_PanckeisXD: Teleported [ADMIN] ivelich350 to [ADMIN] Mr_PanckeisXD]
# [03:35:52 INFO]: iYooyo issued server command: //brush smooth 3
# [03:35:56 INFO]: Mr_PanckeisXD issued server command: /kill ivelich350
# [03:35:56 INFO]: Set the weather to rain & thunder
# [03:35:56 INFO]: ivelich350 ha muerto y ahora descanza en paz.
# [03:35:56 INFO]: Este es el comienzo del sufrimiento eterno de ivelich350. ¡HA SIDO GLITCHEADO!
# [03:35:56 INFO]: X: -27 || Y: 104 || Z: -7
# [03:35:56 INFO]: [ADMIN] ivelich350 was killed
# [03:35:56 INFO]: [[ADMIN] Mr_PanckeisXD: Killed [ADMIN] ivelich350]
# [03:35:59 INFO]: <iYooyo> ez
# [03:36:01 INFO]: ¡Comienza el GLITCH Train con duración de 3 horas!
# [03:36:07 INFO]: ivelich350 issued server command: /gamemode creative
# [03:36:07 INFO]: [[ADMIN] ivelich350: Set own game mode to Creative Mode]
# [03:36:14 INFO]: Mr_PanckeisXD issued server command: /give @p minecraft:player_head{SkulllOwner:"iYooyo"}
# [03:36:14 INFO]: [[ADMIN] Mr_PanckeisXD: Gave 1 [Player Head] to [ADMIN] Mr_PanckeisXD]
# [03:37:05 INFO]: iYooyo issued server command: //replacenear 25 stone 35%cracked_nether_bricks,35%nether_bricks,5%magma_block,10%coal_block,15%obsidian
# [03:37:10 INFO]: iYooyo issued server command: //undo
# [03:37:13 INFO]: iYooyo issued server command: //replacenear 50 stone 35%cracked_nether_bricks,35%nether_bricks,5%magma_block,10%coal_block,15%obsidian
# [03:37:57 INFO]: ivelich350 lost connection: Disconnected
# [03:37:57 INFO]: [voicechat] Disconnecting client [ADMIN] ivelich350
# [03:37:57 INFO]: ivelich350 ha abandonado el glitch.
# [03:38:06 INFO]: com.mojang.authlib.GameProfile@41b95d66[id=d2e30025-3fb2-352c-9ac7-b279fb2f79ee,name=ivelich350,properties={},legacy=false] (/127.0.0.1:38824) lost connection: Disconnected
# [03:38:10 INFO]: ivelich350 se ha unido al glitch.
# [03:38:10 INFO]: ivelich350[/127.0.0.1:32868] logged in with entity id 33213 at ([world]-30.515273875728465, 105.74421435011244, -8.836834083087105)
# [03:38:10 INFO]: [voicechat] Received secret request of [ADMIN] ivelich350 (18)
# [03:38:10 INFO]: [voicechat] Sent secret to [ADMIN] ivelich350
# [03:38:17 INFO]: ivelich350 issued server command: /tp iYooyo
# [03:38:17 INFO]: [[ADMIN] ivelich350: Teleported [ADMIN] ivelich350 to [ADMIN] iYooyo]
# [03:38:26 INFO]: ivelich350 lost connection: Disconnected
# [03:38:26 INFO]: [voicechat] Disconnecting client [ADMIN] ivelich350
# [03:38:26 INFO]: ivelich350 ha abandonado el glitch.
# [03:38:41 INFO]: <Mr_PanckeisXD> yoyo te dejo me tengo que ir o si no me putean
# [03:38:43 INFO]: <Mr_PanckeisXD> XD
# [03:38:47 INFO]: <iYooyo> oka
# [03:38:48 INFO]: <Mr_PanckeisXD> gracias por tu ayuda
# [03:38:51 INFO]: <iYooyo> dale pa
# [03:38:53 INFO]: <iYooyo> nv
# [03:39:02 INFO]: <Mr_PanckeisXD> ya hasta te dejamos tu easter egg
# [03:39:12 INFO]: <iYooyo> xd
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [03:39:39 INFO]: Mr_PanckeisXD lost connection: Disconnected
# [03:39:39 INFO]: [voicechat] Disconnecting client [ADMIN] Mr_PanckeisXD
# [03:39:39 INFO]: Mr_PanckeisXD ha abandonado el glitch.
# [03:40:21 INFO]: iYooyo issued server command: //replacenear stone 40%cracked_nether_bricks,40%nether_bricks,5%magma_block,15%red_nether_bricks
# [03:40:26 INFO]: iYooyo issued server command: //replacenear 25 stone 40%cracked_nether_bricks,40%nether_bricks,5%magma_block,15%red_nether_bricks
# [03:40:31 INFO]: iYooyo issued server command: //replacenear 50 stone 40%cracked_nether_bricks,40%nether_bricks,5%magma_block,15%red_nether_bricks
# [03:41:12 INFO]: iYooyo issued server command: //replacenear 50 stone 40%cracked_nether_bricks,40%nether_bricks,5%magma_block,15%red_nether_bricks
# [03:41:15 INFO]: iYooyo issued server command: //replacenear 50 stone 40%cracked_nether_bricks,40%nether_bricks,5%magma_block,15%red_nether_bricks
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [03:55:27 INFO]: iYooyo issued server command: /up 100
# [03:55:31 INFO]: iYooyo issued server command: /up 150
# [03:55:46 INFO]: iYooyo issued server command: //cyl black_wool 25
# [03:55:55 INFO]: iYooyo issued server command: //cyl 25 black_wool
# [03:56:29 INFO]: iYooyo issued server command: //cyl minecraft:black_wool 25 5
# [03:56:50 INFO]: iYooyo issued server command: //brush cyl black_wool
# [03:56:52 INFO]: iYooyo issued server command: //brush cyl black_wool 5
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [03:59:46 INFO]: iYooyo issued server command: //copy
# [03:59:58 INFO]: iYooyo issued server command: //cut
# [04:00:04 INFO]: iYooyo issued server command: /up 200
# [04:00:07 INFO]: iYooyo issued server command: //paste
# [04:00:19 INFO]: iYooyo issued server command: /up 1
# [04:00:21 INFO]: iYooyo issued server command: //paste
# [04:00:24 INFO]: iYooyo issued server command: //undo
# [04:00:30 INFO]: iYooyo issued server command: //copy
# [04:00:50 INFO]: iYooyo issued server command: //cut
# [04:00:54 INFO]: iYooyo issued server command: //paste
# [04:01:12 INFO]: iYooyo issued server command: //cut
# [04:01:15 INFO]: iYooyo issued server command: //paste
# [04:01:28 INFO]: iYooyo issued server command: //copy
# [04:01:37 INFO]: iYooyo issued server command: //set 0
# [04:01:54 INFO]: iYooyo issued server command: //cut
# [04:03:39 INFO]: iYooyo issued server command: //undo
# [04:03:40 INFO]: iYooyo issued server command: //undo
# [04:05:01 INFO]: iYooyo issued server command: //brush cyl green_wool,green_terracotta,green_concrete 5
# [04:05:57 INFO]: iYooyo issued server command: //brush cyl black_wool 5
# [04:06:31 INFO]: iYooyo issued server command: //replacenear green_wool,green_terracotta,green_concrete stone
# [04:06:35 INFO]: iYooyo issued server command: //replacenear 100 green_wool,green_terracotta,green_concrete stone
# [04:07:06 INFO]: iYooyo issued server command: //replacenear 100 stone purple_terracotta,purple_wool,purple_concrete
# [04:07:14 INFO]: iYooyo issued server command: //undo
# [04:07:44 INFO]: iYooyo issued server command: //replacenear 100 stone 40%red_wool,30%red_terracotta,30%red_concrete
# [04:08:03 INFO]: iYooyo issued server command: //brush cyl black_wool 5
# [04:08:06 INFO]: iYooyo issued server command: /up 200
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [04:09:58 WARN]: iYooyo moved too quickly! -5.978834453535455,7.2805876121650215,3.3807076666180365
# [04:10:40 INFO]: iYooyo issued server command: /tps
# [04:11:55 INFO]: iYooyo issued server command: //replacenear 40%red_wool,30%red_terracotta,30%red_concrete stone
# [04:11:58 INFO]: iYooyo issued server command: //replacenear 100 40%red_wool,30%red_terracotta,30%red_concrete stone
# [04:12:08 INFO]: iYooyo issued server command: //replacenear 100 red_wool,red_terracotta,red_concrete stone
# [04:12:26 INFO]: iYooyo issued server command: //replace stone 30%red_wool,30%red_terracotta,30%red_concrete,10%magma_block
# [04:12:30 INFO]: iYooyo issued server command: //replace 100 stone 30%red_wool,30%red_terracotta,30%red_concrete,10%magma_block
# [04:12:38 INFO]: iYooyo issued server command: //replacenear 100 stone 30%red_wool,30%red_terracotta,30%red_concrete,10%magma_block
# [04:12:59 INFO]: iYooyo issued server command: //undo
# [04:12:59 INFO]: iYooyo issued server command: //replacenear 100 stone 25%red_wool,25%red_terracotta,25%red_concrete,25%magma_block
# [04:13:08 INFO]: iYooyo issued server command: //undo
# [04:13:22 INFO]: iYooyo issued server command: //replacenear 100 stone 20%red_wool,20%red_terracotta,20%red_concrete,40%magma_block
# [04:14:30 INFO]: iYooyo issued server command: //undo
# [04:14:31 INFO]: iYooyo issued server command: //replacenear 100 stone 33%red_wool,33%red_terracotta,33%red_concrete,1%magma_block
# [04:14:43 INFO]: iYooyo issued server command: //undo
# [04:14:56 INFO]: iYooyo issued server command: //replacenear 100 stone red_wool,red_concrete
# [04:15:26 INFO]: iYooyo issued server command: //brush cyl black_wool 25
# [04:15:55 INFO]: iYooyo issued server command: /worldedit cui
# [04:15:59 INFO]: iYooyo issued server command: /worldedit help
# [04:16:13 INFO]: iYooyo issued server command: /ascend
# [04:16:17 INFO]: iYooyo issued server command: /ascend
# [04:16:27 INFO]: iYooyo issued server command: /biomelist
# [04:16:39 INFO]: iYooyo issued server command: //calculate 5x5
# [04:16:41 INFO]: iYooyo issued server command: //calculate 5.5
# [04:16:53 INFO]: iYooyo issued server command: //calculate 5 + 5
# [04:16:57 INFO]: iYooyo issued server command: //calculate 5 x 5
# [04:16:59 INFO]: iYooyo issued server command: //calculate 5 . 5
# [04:17:02 INFO]: iYooyo issued server command: //calculate 5 % 5
# [04:17:08 INFO]: iYooyo issued server command: //calculate 5 : 5
# [04:17:14 INFO]: iYooyo issued server command: /worldedit help -s -p 2
# [04:17:22 INFO]: iYooyo issued server command: /worldedit help -s -p 3
# [04:17:24 INFO]: iYooyo issued server command: /worldedit help -s -p 4
# [04:17:33 INFO]: iYooyo issued server command: /deltree
# >
